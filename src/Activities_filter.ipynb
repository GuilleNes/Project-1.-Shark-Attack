# %%
import pandas as pd
import re

# %%
attacks_filtered = pd.read_csv("../data/Attacks_filtered2.csv")

attacks_filtered
# Out:
#             Type             Country               Area      Activity Sex  \
# 0        Boating                 USA         California      Paddling   F
# 1     Unprovoked                 USA            Georgia      Standing   F
# 2        Invalid                 USA             Hawaii       Surfing   M
# 3     Unprovoked           AUSTRALIA    New South Wales       Surfing   M
# 4       Provoked              MEXICO             Colima   Free diving   M
# ...          ...                 ...                ...           ...  ..
# 4947  Unprovoked           AUSTRALIA    New South Wales      Swimming   M
# 4948  Unprovoked           AUSTRALIA  Western Australia        Diving   M
# 4949  Unprovoked           AUSTRALIA  Western Australia  Pearl diving   M
# 4950  Unprovoked                 USA     North Carolina      Swimming   M
# 4951  Unprovoked  CEYLON (SRI LANKA)   Eastern Province      Swimming   M
#
#      Fatal (Y/N)           Time  \
# 0              N          18h00
# 1              N  14h00  -15h00
# 2              N          07h45
# 3              N            NaN
# 4              N            NaN
# ...          ...            ...
# 4947           Y            NaN
# 4948           Y            NaN
# 4949           Y            NaN
# 4950           Y            NaN
# 4951           Y            NaN
#
#                                  Investigator or Source    Year Month
# 0                                      R. Collier, GSAF  2018.0   Jun
# 1                        K.McMurray, TrackingSharks.com  2018.0   Jun
# 2                        K.McMurray, TrackingSharks.com  2018.0   Jun
# 3                                        B. Myatt, GSAF  2018.0   Jun
# 4                                             A .Kipper  2018.0   Jun
# ...                                                 ...     ...   ...
# 4947  L. Becke in New York Sun, 9/9/1906; L. Schultz...  1906.0   NaN
# 4948                   H. Taunton; N. Bartlett,  p. 234  1903.0   NaN
# 4949              H. Taunton; N. Bartlett,  pp. 233-234  1903.0   NaN
# 4950               F. Schwartz, p.23; C. Creswell, GSAF  1900.0   NaN
# 4951                                         S.W. Baker  1845.0   NaN
#
# [4952 rows x 10 columns]

# %%
attacks_filtered["Activity"].value_counts()
# Out:
# Surfing                                                                                940
# Swimming                                                                               756
# Fishing                                                                                316
# Spearfishing                                                                           286
# Wading                                                                                 141
#                                                                                       ...
# Longline fishing for sharks                                                              1
# Feeding a shark                                                                          1
# The shrimper Loless Maurine capsized in heavy seas & the men were swimming ashore        1
# Swimming in the channel                                                                  1
# 4 men were bathing                                                                       1
# Name: Activity, Length: 1226, dtype: int64

# %%
# %run Functions.ipynb 
        
# filter_activity(attacks_filtered["Activity"])
for i in attacks_filtered["Activity"]:
    i = str(i)
    if "swim" in i or "Swim" in i:
            attacks_filtered["Activity"] = attacks_filtered["Activity"].replace(i, "Swimming related")
    elif "surf" in i or "Surf" in i or "Board" in i or "board" in i or "Pad" in i or "pad" in i:
            attacks_filtered["Activity"] = attacks_filtered["Activity"].replace(i, "Board involved activity")
    elif "fish" in i or "Fish" in i or "Kill" in i or "Pull" in i or "Pick" in i or "feed" in i:
            attacks_filtered["Activity"] = attacks_filtered["Activity"].replace(i, "Fishing related")
    elif "Wad" in i or "Bath" in i or "bath"in i or "Stand"in i or "Play" in i or "play" in i or "Walk" in i or "walk" in i:
            attacks_filtered["Activity"] = attacks_filtered["Activity"].replace(i, "Beach activities")
    elif "Div" in i or "div" in i or "underw" in i:
            attacks_filtered["Activity"] = attacks_filtered["Activity"].replace(i, "Diving activities")
    elif "dinghy" in i or "collide" in i or "lifeboat" in i or "explodex" in i or "skiff" in i:
            attacks_filtered["Activity"] = attacks_filtered["Activity"].replace(i, "Consequence of a shipwreck")
    elif "Shark"in i or "shark" in i:
            attacks_filtered["Activity"] = attacks_filtered["Activity"].replace(i, "Consequence of handeling sharks")
    else:
            attacks_filtered["Activity"] = attacks_filtered["Activity"].replace(i, "Other random, unclassifiable or silly activities")

# %%
attacks_filtered["Activity"].value_counts()
# Out:
# Board involved activity                             1450
# Swimming related                                     988
# Fishing related                                      935
# Other random, unclassifiable or silly activities     547
# Beach activities                                     462
# Diving activities                                    422
# Consequence of handeling sharks                       89
# Consequence of a shipwreck                            13
# Name: Activity, dtype: int64

# %%
attacks_filtered.sample()
# Out:
#            Type Country     Area                 Activity Sex Fatal (Y/N)  \
# 152  Unprovoked     USA  Florida  Board involved activity   M           N
#
#       Time       Investigator or Source    Year Month
# 152  10h00  Orlando Sentinel, 3/27/2017  2017.0   Mar

# %%
attacks_filtered.to_csv("../data/Attacks_filtered3.csv", index=False)
