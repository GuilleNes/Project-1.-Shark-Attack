# %%
import pandas as pd
import re

# %%
attacks_filtered = pd.read_csv("../data/Attacks_filtered.csv")

attacks_filtered
# Out:
#             Type             Country               Area  \
# 0        Boating                 USA         California
# 1     Unprovoked                 USA            Georgia
# 2        Invalid                 USA             Hawaii
# 3     Unprovoked           AUSTRALIA    New South Wales
# 4       Provoked              MEXICO             Colima
# ...          ...                 ...                ...
# 4947  Unprovoked           AUSTRALIA    New South Wales
# 4948  Unprovoked           AUSTRALIA  Western Australia
# 4949  Unprovoked           AUSTRALIA  Western Australia
# 4950  Unprovoked                 USA     North Carolina
# 4951  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
#                                               Activity Sex Fatal (Y/N)  \
# 0                              Board involved activity   F           N
# 1     Other random, unclassifiable or silly activities   F           N
# 2                              Board involved activity   M           N
# 3                              Board involved activity   M           N
# 4                                    Diving activities   M           N
# ...                                                ...  ..         ...
# 4947                                  Swimming related   M           Y
# 4948                                 Diving activities   M           Y
# 4949                                 Diving activities   M           Y
# 4950                                  Swimming related   M           Y
# 4951                                  Swimming related   M           Y
#
#                Time                             Investigator or Source  \
# 0             18h00                                   R. Collier, GSAF
# 1     14h00  -15h00                     K.McMurray, TrackingSharks.com
# 2             07h45                     K.McMurray, TrackingSharks.com
# 3               NaN                                     B. Myatt, GSAF
# 4               NaN                                          A .Kipper
# ...             ...                                                ...
# 4947            NaN  L. Becke in New York Sun, 9/9/1906; L. Schultz...
# 4948            NaN                   H. Taunton; N. Bartlett,  p. 234
# 4949            NaN              H. Taunton; N. Bartlett,  pp. 233-234
# 4950            NaN               F. Schwartz, p.23; C. Creswell, GSAF
# 4951            NaN                                         S.W. Baker
#
#         Year Month
# 0     2018.0   Jun
# 1     2018.0   Jun
# 2     2018.0   Jun
# 3     2018.0   Jun
# 4     2018.0   Jun
# ...      ...   ...
# 4947  1906.0   NaN
# 4948  1903.0   NaN
# 4949  1903.0   NaN
# 4950  1900.0   NaN
# 4951  1845.0   NaN
#
# [4952 rows x 10 columns]

# %%
attacks_filtered["Activity"].value_counts()
# Out:
# Board involved activity                             1450
# Other random, unclassifiable or silly activities    1009
# Swimming related                                     988
# Fishing related                                      935
# Diving activities                                    422
# Consequence of handeling sharks                       89
# Consequence of a shipwreck                            13
# Name: Activity, dtype: int64

# %%
# def filter_activity (list):

for i in attacks_filtered["Activity"]:
    i = str(i)
    if "swim" in i or "Swim" in i:
        attacks_filtered["Activity"] = attacks_filtered["Activity"].replace(i, "Swimming related")
    elif "surf" in i or "Surf" in i or "Board" in i or "board" in i or "Pad" in i or "pad" in i:
        attacks_filtered["Activity"] = attacks_filtered["Activity"].replace(i, "Board involved activity")
    elif "fish" in i or "Fish" in i or "Kill" in i or "Pull" in i or "Pick" in i or "feed" in i:
        attacks_filtered["Activity"] = attacks_filtered["Activity"].replace(i, "Fishing related")
    elif "Wad" in i or "Bath" in i or "bath"in i or "Stand"in i or "Play" in i or "play" in i or "Walk" in i or "walk" in i:
        attacks_filtered["Activity"] = attacks_filtered["Activity"].replace(i, "Beach activities")
    elif "Div" in i or "div" in i or "underw" in i:
        attacks_filtered["Activity"] = attacks_filtered["Activity"].replace(i, "Diving activities")
    elif "dinghy" in i or "collide" in i or "lifeboat" in i or "explodex" in i or "skiff" in i:
        attacks_filtered["Activity"] = attacks_filtered["Activity"].replace(i, "Consequence of a shipwreck")
    elif "Shark"in i or "shark" in i:
        attacks_filtered["Activity"] = attacks_filtered["Activity"].replace(i, "Consequence of handeling sharks")
    else:
        attacks_filtered["Activity"] = attacks_filtered["Activity"].replace(i, "Other random, unclassifiable or silly activities")

# %%
attacks_filtered["Activity"].value_counts()
# Out:
# Board involved activity                             1450
# Other random, unclassifiable or silly activities    1022
# Swimming related                                     988
# Fishing related                                      935
# Diving activities                                    422
# Consequence of handeling sharks                       89
# Name: Activity, dtype: int64

# %%
attacks_filtered.sample()
# Out:
#             Type           Country                Area  \
# 1664  Unprovoked  PAPUA NEW GUINEA  Milne Bay Province
#
#                                               Activity Sex Fatal (Y/N) Time  \
# 1664  Other random, unclassifiable or silly activities   M           N  NaN
#
#                 Investigator or Source    Year Month
# 1664  PNG Post-Courier, 6/13/2002, p.5  2002.0   May

# %%
attacks_filtered.to_csv("../data/Attacks_filtered.csv", index=False)
