# %%
import pandas as pd
import re

# %%
attacks_filtered = pd.read_csv("../data/Attacks_filtered3.csv")

attacks_filtered
# Out:
#             Type             Country               Area  \
# 0        Boating                 USA         California
# 1     Unprovoked                 USA            Georgia
# 2        Invalid                 USA             Hawaii
# 3     Unprovoked           AUSTRALIA    New South Wales
# 4       Provoked              MEXICO             Colima
# ...          ...                 ...                ...
# 4947  Unprovoked           AUSTRALIA    New South Wales
# 4948  Unprovoked           AUSTRALIA  Western Australia
# 4949  Unprovoked           AUSTRALIA  Western Australia
# 4950  Unprovoked                 USA     North Carolina
# 4951  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
#                      Activity Sex Fatal (Y/N)           Time  \
# 0     Board involved activity   F           N          18h00
# 1            Beach activities   F           N  14h00  -15h00
# 2     Board involved activity   M           N          07h45
# 3     Board involved activity   M           N            NaN
# 4           Diving activities   M           N            NaN
# ...                       ...  ..         ...            ...
# 4947         Swimming related   M           Y            NaN
# 4948        Diving activities   M           Y            NaN
# 4949        Diving activities   M           Y            NaN
# 4950         Swimming related   M           Y            NaN
# 4951         Swimming related   M           Y            NaN
#
#                                  Investigator or Source    Year Month
# 0                                      R. Collier, GSAF  2018.0   Jun
# 1                        K.McMurray, TrackingSharks.com  2018.0   Jun
# 2                        K.McMurray, TrackingSharks.com  2018.0   Jun
# 3                                        B. Myatt, GSAF  2018.0   Jun
# 4                                             A .Kipper  2018.0   Jun
# ...                                                 ...     ...   ...
# 4947  L. Becke in New York Sun, 9/9/1906; L. Schultz...  1906.0   NaN
# 4948                   H. Taunton; N. Bartlett,  p. 234  1903.0   NaN
# 4949              H. Taunton; N. Bartlett,  pp. 233-234  1903.0   NaN
# 4950               F. Schwartz, p.23; C. Creswell, GSAF  1900.0   NaN
# 4951                                         S.W. Baker  1845.0   NaN
#
# [4952 rows x 10 columns]

# %% [markdown]
# We are going to focus in column "Time", trying to clean as many data as possible

# %%
print(list(attacks_filtered["Time"]))
# Out:
# ['18h00', '14h00  -15h00', '07h45', nan, nan, nan, 'Late afternoon', nan, '17h00', '14h00', 'Morning', nan, '15h00', '08h15', nan, '11h00', '10h30', nan, '10h40', '16h50', '07h00', '09h30', 'Afternoon', '21h50', '09h40', nan, nan, nan, '08h00', '09h30', nan, '18h00', '15h00', '09h30', '17h35', '15h30', '07h30', nan, '19h00, Dusk', 'Night', '16h00', '18h00', nan, nan, nan, '08h00', '15h30', '15h01', nan, 'Late afternoon', nan, '18h00', '12h00', nan, nan, nan, '13h45', 'Late afternoon', '16h00', '23h30', nan, '09h00', '15h00', 'Afternoon', '17h00', '08h00', 'Afternoon', '09h00', '14h30', '18h30', '12h30', 'Morning', '18h00', '15h30', '14h00', 'Morning', nan, '16h30', 'Afternoon', 'Night', '18h45', '15h00', '06h00', 'Morning', '10h00', nan, nan, '10h44', '10h30', '13h19', 'Midday', nan, '10h00', '15h00', '13h30', nan, '23h30', '10h45', '18h30', '15h00', 'Afternoon', nan, nan, '17h00', 'Afternoon', '12h30', '11h20', '07h45', '18h30', '11h45', '11h00', '15h30', nan, '15h00', '19h30', nan, 'Morning', nan, '10h00', '12h00', nan, '08h30', '15h45', '10h00', nan, nan, 'Shortly before 12h00', nan, 'Morning', nan, 'Morning', nan, '17h00', '14h30', '17h34', '17h10', '11h00', '11h15', '14h00', '16h00', '08h50', '16h00', '09h00', '13h30', '13h45', '16h00', '17h45', '17h00', nan, '13h00', 'Afternoon', '15h00', '10h00', '18h30', '14h30', nan, nan, 'Morning', 'Morning', '09h30', '10h20', '13h30', 'Afternoon', nan, nan, '13h20', '14h00', '12h00', '13h30', 'Morning', '07h30', '12h30', '18h00', '17h00', 'Morning', '07h00', '09h30', nan, 'Afternoon', '02h00', '09h00', '11h00', '10h30', 'Afternoon', 'Afternoon', '07h30', '17h00', '18h00', '09h50', '10h30', '16h00', '11h30', '17h30', '9h00', '13h00', '11h00', '10h43', 'After noon', nan, nan, '15h15', '14h30', '15h40', 'Late afternoon', 'Late afternoon', nan, nan, '15h00', '14h00', '17h00', '16h00', nan, '16h30', nan, '11h30', nan, nan, nan, '12h00', '19h05', nan, nan, 'After noon', '1300', '11h00', '17h00', nan, nan, nan, '10h00', nan, '14h30 / 15h30', '22h00', '16h20', '14h34', '11h00', nan, '15h25', '14h55', '06h00', nan, '17h30', '15h00', '11h30', '08h30', '11h30', 'Morning', 'Afternoon', '16h00', '16h00', '15h45', '12h00', '18h00', '17h46', 'Morning ', '13h20', '15h49', 'Afternoon', '07h00', '17h30', '08h00', '12h00', 'Morning', 'Morning', nan, '10h45', '11h00', '19h00', '11h00', '13h30', 'Afternoon', 'Afternoon', 'Midnight', nan, '19h00', '16h00', '15h00', '12h30', '13h20', 'Late afternoon', nan, nan, '14h00', '11h30', '09h30 / 10h00', nan, 'Morning', nan, 'Afternoon', '11h30', 'Morning', nan, 'Morning', '07h00', nan, '10h30', 'Morning', '10h15', 'Afternoon', '11h00', nan, '18h15', '11h00', '11h00', '14h00', '04h00', nan, '14h50', '15h00', '14h30', '13h50', nan, '19h20', '11h30', '11h00', '16h20', '10h25', nan, '16h50', '13h00', '10h00', '08h30', '16h20', 'Afternoon', '10h45-11h15', '16h45', '15h52', '12h30', '07h30', nan, '19h00', '15h00', '06h15', '17h30', '14h40', '11h30', '16h00', '08h30', '10h25', '10h00', '17h10', '12h30', '15h30', '07h30', '11h00', '08h00', '06h00', nan, '19h00', '10h10', '10h00', nan, nan, nan, '08h45', nan, 'Evening', '09h00', '09h00', '12h10', nan, '18h05', '16h00', '14h40', '19h30', '16h00', '11h00', nan, '11h41', '12h25', '09h30', nan, 'Morning', '13h00', '17h51', '16h12', '12h45', '10h50', nan, '15h00', '15h00', '13h45', '08h00', nan, '10h30', '14h15', '15h00', '15h00', '13h00', '09h00', '16h30', '09h45', '11h00', nan, '09h00', '07h30', 'Afternoon', '11h00', nan, '11h45', '10h00', 'Morning', '10h20', nan, '18h30', '10h00', '06h45', nan, '05h00', '03h30', nan, 'Afternoon', nan, '13h45', nan, 'Night', '16h00', '08h00', 'Afternoon', 'Morning', 'Morning', '11h30', 'Morning', '11h30', '07h00', 'Sometime between 06h00 & 08hoo', nan, nan, '13h00', '13h30', '06h30', '16h30', '11h00', '18h00', '10h00', '08h00', nan, '11h15', '06h30', nan, '15h30', '17h20', '11h30', 'Afternoon', '11h00', '14h00', '11h30', '17h30', '11h00', '11h30', nan, '18h45', '10h45', '13h00', '18h00', '20 ...

# %%
# %run Functions.ipynb 
# filter_time(attacks_filtered["Time"])
for i in attacks_filtered["Time"]:
        i = str(i)

        if "06" in i or "07"  in i or "08" in i or "09" in i or "10" in i or "11" in i or "morning" in i or "Morning" in i or "A.M" in i or "AM" in i or "dawn" in i or "Dawn"in i:
            attacks_filtered["Time"] = attacks_filtered["Time"].replace(i, "Morning")

        elif "12" in i or "13"in i or "14"in i or "15"in i or "16"in i or "17"in i or "afternoon"in i or "lunch"in i or "noon"in i or "Noon"in i or "Midday"in i or "P.M." in i:      
            attacks_filtered["Time"] = attacks_filtered["Time"].replace(i, "Afternoon")

        elif "18"in i or "19"in i or "20"in i or "21"in i or "Sunset"in i or "dusk"in i or "Dusk"in i or "evening" in i:
            attacks_filtered["Time"] = attacks_filtered["Time"].replace(i, "Evening")

        elif "22"in i or "23"in i or "24"in i or "01"in i or "02"in i or "03"in i or "04"in i or "05"in i or "Night"in i or "night"in i:
            attacks_filtered["Time"] = attacks_filtered["Time"].replace(i, "Nightime")
            
#         else:
#              attacks_filtered["Time"] = attacks_filtered["Time"].replace(i, "Random, or not clear time references")

# %%
print(list(attacks_filtered["Time"]))
# Out:
# ['Evening', 'Afternoon', 'Morning', nan, nan, nan, 'Afternoon', nan, 'Afternoon', 'Afternoon', 'Morning', nan, 'Afternoon', 'Morning', nan, 'Morning', 'Morning', nan, 'Morning', 'Afternoon', 'Morning', 'Morning', 'Afternoon', 'Evening', 'Morning', nan, nan, nan, 'Morning', 'Morning', nan, 'Evening', 'Afternoon', 'Morning', 'Afternoon', 'Afternoon', 'Morning', nan, 'Evening', 'Nightime', 'Afternoon', 'Evening', nan, nan, nan, 'Morning', 'Afternoon', 'Afternoon', nan, 'Afternoon', nan, 'Evening', 'Afternoon', nan, nan, nan, 'Afternoon', 'Afternoon', 'Afternoon', 'Nightime', nan, 'Morning', 'Afternoon', 'Afternoon', 'Afternoon', 'Morning', 'Afternoon', 'Morning', 'Afternoon', 'Evening', 'Afternoon', 'Morning', 'Evening', 'Afternoon', 'Afternoon', 'Morning', nan, 'Afternoon', 'Afternoon', 'Nightime', 'Evening', 'Afternoon', 'Morning', 'Morning', 'Morning', nan, nan, 'Morning', 'Morning', 'Afternoon', 'Afternoon', nan, 'Morning', 'Afternoon', 'Afternoon', nan, 'Nightime', 'Morning', 'Evening', 'Afternoon', 'Afternoon', nan, nan, 'Afternoon', 'Afternoon', 'Afternoon', 'Morning', 'Morning', 'Evening', 'Morning', 'Morning', 'Afternoon', nan, 'Afternoon', 'Evening', nan, 'Morning', nan, 'Morning', 'Afternoon', nan, 'Morning', 'Afternoon', 'Morning', nan, nan, 'Afternoon', nan, 'Morning', nan, 'Morning', nan, 'Afternoon', 'Afternoon', 'Afternoon', 'Morning', 'Morning', 'Morning', 'Afternoon', 'Afternoon', 'Morning', 'Afternoon', 'Morning', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', nan, 'Afternoon', 'Afternoon', 'Afternoon', 'Morning', 'Evening', 'Afternoon', nan, nan, 'Morning', 'Morning', 'Morning', 'Morning', 'Afternoon', 'Afternoon', nan, nan, 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Morning', 'Morning', 'Afternoon', 'Evening', 'Afternoon', 'Morning', 'Morning', 'Morning', nan, 'Afternoon', 'Nightime', 'Morning', 'Morning', 'Morning', 'Afternoon', 'Afternoon', 'Morning', 'Afternoon', 'Evening', 'Morning', 'Morning', 'Afternoon', 'Morning', 'Afternoon', '9h00', 'Afternoon', 'Morning', 'Morning', 'Afternoon', nan, nan, 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', nan, nan, 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', nan, 'Afternoon', nan, 'Morning', nan, nan, nan, 'Afternoon', 'Evening', nan, nan, 'Afternoon', 'Afternoon', 'Morning', 'Afternoon', nan, nan, nan, 'Morning', nan, 'Afternoon', 'Nightime', 'Afternoon', 'Afternoon', 'Morning', nan, 'Afternoon', 'Afternoon', 'Morning', nan, 'Afternoon', 'Afternoon', 'Morning', 'Morning', 'Morning', 'Morning', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Evening', 'Afternoon', 'Morning', 'Afternoon', 'Afternoon', 'Afternoon', 'Morning', 'Afternoon', 'Morning', 'Afternoon', 'Morning', 'Morning', nan, 'Morning', 'Morning', 'Evening', 'Morning', 'Afternoon', 'Afternoon', 'Afternoon', 'Nightime', nan, 'Evening', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', nan, nan, 'Afternoon', 'Morning', 'Morning', nan, 'Morning', nan, 'Afternoon', 'Morning', 'Morning', nan, 'Morning', 'Morning', nan, 'Morning', 'Morning', 'Morning', 'Afternoon', 'Morning', nan, 'Afternoon', 'Morning', 'Morning', 'Afternoon', 'Nightime', nan, 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', nan, 'Evening', 'Morning', 'Morning', 'Afternoon', 'Morning', nan, 'Afternoon', 'Afternoon', 'Morning', 'Morning', 'Afternoon', 'Afternoon', 'Morning', 'Afternoon', 'Afternoon', 'Afternoon', 'Morning', nan, 'Evening', 'Afternoon', 'Morning', 'Afternoon', 'Afternoon', 'Morning', 'Afternoon', 'Morning', 'Morning', 'Morning', 'Morning', 'Afternoon', 'Afternoon', 'Morning', 'Morning', 'Morning', 'Morning', nan, 'Evening', 'Morning', 'Morning', nan, nan, nan, 'Morning', nan, 'Evening', 'Morning', 'Morning', 'Morning', nan, 'Evening', 'Afternoon', 'Afternoon', 'Evening', 'Afternoon', 'Morning', nan, 'Morning', 'Afternoon', 'Morning', nan, 'Morning', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Morning', nan, 'Afternoon', 'Afternoon', ' ...

# %%
attacks_filtered["Time"].value_counts()
# Out:
# Afternoon                                                                1555
# Morning                                                                   951
# Evening                                                                   257
# Nightime                                                                  115
# --                                                                          5
# Late afternon                                                               2
# Dark                                                                        2
#                                                                             2
# Daybreak                                                                    1
#                                                                             1
# FATAL  (Wire netting installed at local beaches after this incident.)       1
# 2 hrs before sunset                                                         1
# "After dark"                                                                1
# Daytime                                                                     1
#                                                                             1
# X                                                                           1
# 2 hours after Opperman                                                      1
# 00h30                                                                       1
# Just before sundown                                                         1
# "Evening"                                                                   1
#                                                                             1
# Lunchtime                                                                   1
# 9h00                                                                        1
# Before daybreak                                                             1
# Name: Time, dtype: int64

# %%
attacks_filtered.to_csv("../data/Attacks_filtered4.csv", index=False)

# %%
attacks_filtered
# Out:
#             Type             Country               Area  \
# 0        Boating                 USA         California
# 1     Unprovoked                 USA            Georgia
# 2        Invalid                 USA             Hawaii
# 3     Unprovoked           AUSTRALIA    New South Wales
# 4       Provoked              MEXICO             Colima
# ...          ...                 ...                ...
# 4947  Unprovoked           AUSTRALIA    New South Wales
# 4948  Unprovoked           AUSTRALIA  Western Australia
# 4949  Unprovoked           AUSTRALIA  Western Australia
# 4950  Unprovoked                 USA     North Carolina
# 4951  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
#                      Activity Sex Fatal (Y/N)       Time  \
# 0     Board involved activity   F           N    Evening
# 1            Beach activities   F           N  Afternoon
# 2     Board involved activity   M           N    Morning
# 3     Board involved activity   M           N        NaN
# 4           Diving activities   M           N        NaN
# ...                       ...  ..         ...        ...
# 4947         Swimming related   M           Y        NaN
# 4948        Diving activities   M           Y        NaN
# 4949        Diving activities   M           Y        NaN
# 4950         Swimming related   M           Y        NaN
# 4951         Swimming related   M           Y        NaN
#
#                                  Investigator or Source    Year Month
# 0                                      R. Collier, GSAF  2018.0   Jun
# 1                        K.McMurray, TrackingSharks.com  2018.0   Jun
# 2                        K.McMurray, TrackingSharks.com  2018.0   Jun
# 3                                        B. Myatt, GSAF  2018.0   Jun
# 4                                             A .Kipper  2018.0   Jun
# ...                                                 ...     ...   ...
# 4947  L. Becke in New York Sun, 9/9/1906; L. Schultz...  1906.0   NaN
# 4948                   H. Taunton; N. Bartlett,  p. 234  1903.0   NaN
# 4949              H. Taunton; N. Bartlett,  pp. 233-234  1903.0   NaN
# 4950               F. Schwartz, p.23; C. Creswell, GSAF  1900.0   NaN
# 4951                                         S.W. Baker  1845.0   NaN
#
# [4952 rows x 10 columns]

# %%
attacks_filtered.isna().sum()
# Out:
# Type                         1
# Country                      1
# Area                        54
# Activity                    46
# Sex                         83
# Fatal (Y/N)                121
# Time                      2047
# Investigator or Source       3
# Year                         0
# Month                      333
# dtype: int64

# %%
attacks_filtered.shape
# Out:
# (4952, 10)
